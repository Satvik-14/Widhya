# %%
import pandas as pd

# %%
data=pd.read_csv('covid19.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       270 non-null    int64
#  1   Date                      270 non-null    object
#  2   State/UnionTerritory      270 non-null    object
#  3   ConfirmedIndianNational   270 non-null    int64
#  4   ConfirmedForeignNational  270 non-null    int64
#  5   Cured                     270 non-null    int64
#  6   Deaths                    270 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 14.9+ KB

# %%
data.head(50)
# Out:
#     Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0     1  30/01/20               Kerala                        1
# 1     2  31/01/20               Kerala                        1
# 2     3  01/02/20               Kerala                        2
# 3     4  02/02/20               Kerala                        3
# 4     5  03/02/20               Kerala                        3
# 5     6  04/02/20               Kerala                        3
# 6     7  05/02/20               Kerala                        3
# 7     8  06/02/20               Kerala                        3
# 8     9  07/02/20               Kerala                        3
# 9    10  08/02/20               Kerala                        3
# 10   11  09/02/20               Kerala                        3
# 11   12  10/02/20               Kerala                        3
# 12   13  11/02/20               Kerala                        3
# 13   14  12/02/20               Kerala                        3
# ...

# %%
df=pd.DataFrame(data)

# %%
d=df["Date"]
c=df["ConfirmedForeignNational"]

# %%
len(d)
# Out:
# 270

# %%
len(c)
# Out:
# 270

# %%
count=0

# %%
for i in range(0,270):
    if d[i]=="04/03/2020":
        count=count+1
count
# Out:
# 0

# %%
c=0
for i in range(0,270):
    if d[i]=="04/03/20":
        c=c+1
c
# Out:
# 6

# %%
c=0
for i in range(0,270):
    if d[i]=="04/03/20":
        c=c+cases[i]+i_cases[i]+de[i]+cu[i]
c
# Out:
# 31

# %%
cases=df["ConfirmedIndianNational"]

# %%
i_cases=df["ConfirmedForeignNational"]

# %%
ind=df.groupby("ConfirmedIndianNational")

# %%
fore=df.groupby("ConfirmedForeignNational",sort=False)

# %%
de=df["Deaths"]
cu=df["Cured"]

# %%
de[7]
# Out:
# 0

# %%
df.groupby("Date",sort=False)

# %%
r=df.groupby("Cured")
r.first()
# Out:
#        Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# Cured
# 0        1  30/01/20               Kerala                        1
# 1      136  14/03/20                Delhi                        7
# 2      150  15/03/20                Delhi                        7
# 3       38  03/03/20               Kerala                        3
# 4      161  15/03/20        Uttar Pradesh                       12
# 5      141  14/03/20        Uttar Pradesh                       11
# 9      226  19/03/20        Uttar Pradesh                       18
#
#        ConfirmedForeignNational  Deaths
# Cured
# 0                             0       0
# 1                             0       1
# 2                             0       1
# 3                             0       0
# 4                             1       0
# 5                             1       0
# 9                             1       0

# %%
de=df["Deaths"]
de[0]
# Out:
# 0

# %%
cou=[]
for i in range(0,270):
    
    if d[i]=="04/03/20":
        c=c+cases[i]+i_cases[i]+de[i]+cu[i]
c
# Out:
# 62

# %%
dat=df.groupby("Date",sort=False).sum()
#
dat
# Out:
#            Sno  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# Date
# 30/01/20     1                        1                         0      0
# 31/01/20     2                        1                         0      0
# 01/02/20     3                        2                         0      0
# 02/02/20     4                        3                         0      0
# 03/02/20     5                        3                         0      0
# 04/02/20     6                        3                         0      0
# 05/02/20     7                        3                         0      0
# 06/02/20     8                        3                         0      0
# 07/02/20     9                        3                         0      0
# 08/02/20    10                        3                         0      0
# 09/02/20    11                        3                         0      0
# 10/02/20    12                        3                         0      0
# ...

# %%
#df2.drop("Sno")
#del df2["Sno"]
df2
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df2=pd.DataFrame(dat)
ci=df2["ConfirmedIndianNational"]
cf=df2["ConfirmedForeignNational"]
cc=df2["Cured"]
cd=df2["Deaths"]

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 30/01/20 to 21/03/20
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       52 non-null     int64
#  1   ConfirmedIndianNational   52 non-null     int64
#  2   ConfirmedForeignNational  52 non-null     int64
#  3   Cured                     52 non-null     int64
#  4   Deaths                    52 non-null     int64
# dtypes: int64(5)
# memory usage: 2.4+ KB

# %%
x=[]
for i in range(0,52):
    g=ci[i]+cf[i]+cc[i]+cd[i]
    x.append(g)

# %%
x
# Out:
# [1,
#  1,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  5,
#  9,
#  31,
#  33,
#  34,
#  37,
#  42,
#  49,
#  61,
#  63,
#  77,
#  85,
#  96,
#  125,
#  129,
#  154,
#  168,
#  197,
#  250,
#  310]

# %% [markdown]
# for i in range(0,52):
#     if df2.Date[]

# %%
df2=df2.reset_index()

# %%
df2.head()
# Out:
#        Date  Sno  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 0  30/01/20    1                        1                         0      0
# 1  31/01/20    2                        1                         0      0
# 2  01/02/20    3                        2                         0      0
# 3  02/02/20    4                        3                         0      0
# 4  03/02/20    5                        3                         0      0
#
#    Deaths
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df2.columns
# Out:
# Index(['Date', 'Sno', 'ConfirmedIndianNational', 'ConfirmedForeignNational',
#        'Cured', 'Deaths'],
#       dtype='object')

# %%
u=[]
s=0
for i in range(0,52):
    if df2.Date[i]=='04/03/20':
        for i in range(i,52):
            u.append(ci[i]+cf[i]+cc[i]+cd[i])
        break;

# %%
u
# Out:
# [31, 33, 34, 37, 42, 49, 61, 63, 77, 85, 96, 125, 129, 154, 168, 197, 250, 310]

# %%
r=[]
for i in range(0,len(u)-1):
    e=(u[i+1]-u[i])/u[i]
    r.append(e)

# %%
len(r)
# Out:
# 17

# %%
from statistics import mean
rate=mean(r)

# %%
rate
# Out:
# 0.14814803793984233

# %%
p_t=31*(e**(rate*26))

# %%
round(p_t,0)
# Out:
# 0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),
            vmin=-1,
            cmap='coolwarm',
            annot=True);
